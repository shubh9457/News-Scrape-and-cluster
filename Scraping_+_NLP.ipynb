# %% [markdown]
# <a href="https://colab.research.google.com/github/shubh9457/News-Scrape-and-cluster/blob/master/Scraping_%2B_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
We need to download the following packages to be used 
in our news scrapping as well as in our 
Language Processing task :-

1. BeautifulSoup4 (bs4) - An awesome web scrapping 
  and DOM Data extraction library.

2. Natural Language Toolkit (nltk) - For processing 
  text, NLTK provides us with lots of great functionality 
  built into it.

3. Scikit-Learn (sklearn) - It is a popular library having 
  a collection of a numerous Machine Learning Algorithms 
  implemented into it that are just ready to use.

"""
# !pip3 install bs4
# !pip3 install nltk
# !pip3 install sklearn
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.6/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4) (4.6.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.15.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn) (0.16.0)

# %%
"""
Importing the following packages - 

1. requests - Requests is an inbuilt python package 
  for making a call to a web URL. It allows HTTP/1.1 
  requests to be carried out in an easy manner.

2. bs4 - An awesome web scrapping 
  and DOM Data extraction library.

3. nltk - For processing text, NLTK provides us with 
  lots of great functionality built into it.

4. sklearn - It is a popular library having a 
  collection of a numerous Machine Learning Algorithms 
  implemented into it that are just ready to use.

5. collections - It is an inbuilt python library that
  contains a great collection of special container
  datatypes.

6. textwrap - It is also an inbuilt package for 
  wrapping up the long text so that it doesn't 
  go out of screen width. (For those who hate 
  horizontal scrolling :p).
"""

import requests
from bs4 import BeautifulSoup

import nltk

# Downloading the stopwords and punkt Tokenizer to be used later
nltk.download('stopwords')
nltk.download('punkt')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

import collections
import textwrap
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
"""
Building a word tokenizer to extract all the 
tokens in the given sentence/text.
"""

def word_tokenizer(text):

        # NLTK provides the way to break text into tokens.
        # Example - Tokenizing the text "Man beats coronavirus"
        # results in ["Man", "beats", "coronavirus"].
        # It is more than just a space separator.

        tokenizer = nltk.word_tokenize(text)

        # While analyzing the english words, since we know that
        # grow, grew, growing, grown and many such words are possible
        # that mean the same. So we stem the word to its minimal form
        # in order to get the least length token which is same in all 
        # such word stemming. Eg - stem('grows') => 'grow' ideally

        porter_stemmer = nltk.stem.PorterStemmer()

        # Stopwords is a list of those words which are very commonly used
        # in the english library and there is not much use of them in
        # clustering. Eg - The articles do not make much sense and so
        # they are included in stopwords

        stopwords = nltk.corpus.stopwords.words('english')
        tokens = []

        for token in tokenizer:
              if token not in stopwords:
                    # Stemming the token, if not present in stopwords
                    # and appending it in tokens list.
                    stemmed_token = porter_stemmer.stem(token)
                    tokens.append(stemmed_token)

        # Returning the list of all the tokens
        return tokens

# %%
"""
Based on features, we will cluster the sentences whose features are 
most similar to one another.
"""

def cluster_sentences(sentences, nb_of_clusters=10):
        # A TF-IDF vectorizer is a bag of words model. It works 
        # on the basis of occurence of a term in a document and
        # the number of documents containing the same term. It 
        # converts a collection of raw text 
        # to a matrix of Term frequency and Inverse 
        # Document Frequency and features.

        tfidf_vectorizer = TfidfVectorizer(tokenizer=word_tokenizer,
                                        lowercase=True)

        # Fitting all the sentences/documents in TF-IDF vectorizer
        # for text to numerical feature matrix.
        
        news_tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)
        
        # Initializing KMeans clustering to segregate the documents
        # on the basis of TF-IDF scores
        
        kmeans = KMeans(n_clusters=nb_of_clusters)
        cost = []

        # Fitting the TF-IDF matrix in the feature space to split out the
        # clusters on the basis of pattern between text.
        
        kmeans.fit(news_tfidf_matrix)

        # Initializing a dictionary/map object for storing all the
        # news clusters.

        clusters = collections.defaultdict(list)
        
        # Since, we got a news index and its corresponding cluster label,
        # we will use it to create the dictionary for clustering the news
        # by their labels and indices.

        for index, label in enumerate(kmeans.labels_):
                clusters[label].append(index)

        # Returning the clusters

        return clusters

# %%
"""
In precious step, we have created the clusters. Now its time 
to get back news articles using the clusters mapping.
"""

def create_cluster(news_articles, num_clusters = 10):
    # Creating a list of all the headlines by using the keys of
    # news articles mapping object.

    headlines = list(news_articles.keys())

    # Creating a list of all the news bodies by using the values of
    # news articles mapping object.

    news_body = list(news_articles.values())

    # Calling the clustering function we wrote earlier for 
    # getting the cluster labels

    clusters = cluster_sentences(headlines, num_clusters)

    # Creating a map for storing the news articles in order of the
    # cluster they are assigned to.
    clustering_results = collections.defaultdict(list)

    news_articles_mapping = {}

    # Creating a map for storing the news articles in order of the
    # cluster they are assigned to.
    for cluster_index in range(num_clusters):
            for index, headline in enumerate(clusters[cluster_index]):
                  # Appending all the similar grouped articles 
                  # in a single clustered map object.
                  clustering_results["Cluster "+ 
                                     str(cluster_index+1)].append(headlines[headline])
                  news_articles_mapping[headlines[headline]] = news_body[headline]
    return (clustering_results, news_articles_mapping)

# %%
# Declaring the url on which we are going to apply scrapping.

url_to_crawl = 'https://inshorts.com/en/read/'

# Since, we will be dealing with HTML content, we will be using HTML parser
parser = 'html.parser'

# Getting the crawled webpage.
response = requests.get(url_to_crawl)

# Converting response to BeatifulSoup object for DOM manipulations
# and extracting text from it
bs4obj = BeautifulSoup(response.text, parser)

# %%
# Printing the bs4 data

print(bs4obj.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <style>
#    /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="manifest.json" rel="manifest"/>
#   <!-- Fallback to homescreen for Chrome   <39 on Android -->
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="inshorts" name="application-name"/>
#   <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
#   <!-- Add to homescreen for Safari on iOS -->
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="inshorts" name="apple-mobile-web-app-title"/>
#   <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
#   <!-- Tile icon for Win8 (144x144 + tile color) -->
#   <meta content="fav/favicon.png" name="msapplication-TileImage"/>
#   <meta content="#424242" name="msapplication-TileColor"/>
#   <meta content="#424242" name="theme-color"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="#424242" name="msapplication-navbutton-color"/>
#    <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
#    <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
#    <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#    <meta content="app" name="twitter:card">
#     <meta content="@inshorts" name="twitter:site">
#      <meta content="@inshorts" name="twitter:creator">
#       <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description">
#        <meta content="IN" name="twitter:app:country">
#         <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone">
#          <meta content="892146527" name="twitter:app:id:iphone">
#           <meta content="nis://news" name="twitter:app:url:iphone">
#            <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad">
#             <meta content="892146527" name="twitter:app:id:ipad">
#              <meta content="nis://news" name="twitter:app:url:ipad">
#               <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
#               <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
#               <meta content="nis://news" name="twitter:app:url:googleplay"/>
#               <meta content="Read short news updates in less than 60 words with inshorts. All daily news updates related to business, sports, technology, India, world and entertainment in English with inshorts" name="description"/>
#               <link href="https://inshorts.com/en/read/" rel="canonical">
#                <link href="https://inshorts.com/en/read/" reflang="en" rel="alternate">
#                 <meta content="app-id=892146527" name="apple-itunes-app"/>
#                 <meta content="app-id=com.nis.app" name="google-play-app"/>
#                 <title>
#                  Breaking News Headlines: Read All News Updates in English | Inshorts
#                 </title>
#                 <!-- CSS  -->
#                 <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
#                 <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#                 <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
#                 <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
#                 <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css">
#                  <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css">
#                   <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css">
#                    <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css">
#                     <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png">
#                      <link href="/dist/manifest.json" rel="manifest"/>
#                      <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#                      </script>
#                      <script>
#                       var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#                      </script>
#                      <!-- Top banner for desktop-->
#                      <script>
#                       googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#                      </script>
#                      <!-- Facebook Pixel Code -->
#                      <script>
#                       !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#                      </script>
#                      <noscript>
#                       <img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#                      </noscript>
#                      <!-- End Facebook Pixel Code -->
#                     </link>
#                    </link>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
#  </script>
#  <body>
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- HEADER START -->
#   <div class="header z-depth-1">
#    <div class="menu clickable">
#     <button class="c-hamburger c-hamburger--htx">
#      <span>
#       toggle menu
#      </span>
#     </button>
#     <span class="unselectable">
#      Menu
#     </span>
#    </div>
#    <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
#    <a href="/">
#     <img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/>
#    </a>
#   </div>
#   <!-- HEADER END -->
#   <!--SIDEBAR START -->
#   <div class="hide-on-med-and-up sidebar-bg" style="display: none;">
#   </div>
#   <div class="sidebar" style="overflow-y: scroll;">
#    <div class="lang-bar" style="">
#     <div class="lang-selector clickable">
#      <a href="/en/read">
#       <div class="lang-en selected">
#        English
#       </div>
#      </a>
#      <a href="/hi/read">
#       <div class="lang-hi ">
#        हिन्दी
#       </div>
#      </a>
#     </div>
#    </div>
#    <div>
#     <div class="category-header">
#      Categories
#     </div>
#     <ul class="category-list">
#      <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });">
#       <li class="active-category selected">
#        All News
#       </li>
#      </a>
#      <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });">
#       <li class="active-category ">
#        India
#       </li>
#      </a>
#      <a "clicked",="" "event",="" "eventaction":="" "eventcategory":="" "eventlabel":="" "linktoindianews",="" "redirectedtoindianews"="" href="/en/read/business" onclick="ga(" send",="" {"hittype":="" });"="">
#       <li class="active-category ">
#        Business
#       </li>
#      </a>
#      <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });">
#       <li class="active-category ">
#        Sports
#       </li>
#      </a>
#      <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });">
#       <li class="active-category ">
#        World
#       </li>
#      </a>
#      <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });">
#       <li class="active-category ">
#        Politics
#       </li>
#      </a>
#      <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });">
#       <li class="active-category ">
#        Technology
#       </li>
#      </a>
#      <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });">
#       <li class="active-category ">
#        Startup
#       </li>
#      </a>
#      <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });">
#       <li class="active-category ">
#        Entertainment
#       </li>
#      </a>
#      <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });">
#       <li class="active-category ">
#        Miscellaneous
#       </li>
#      </a>
#      <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });">
#       <li class="active-category ">
#        Hatke
#       </li>
#      </a>
#      <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });">
#       <li class="active-category ">
#        Science
#       </li>
#      </a>
#      <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });">
#       <li class="active-category ">
#        Automobile
#       </li>
#      </a>
#     </ul>
#    </div>
#   </div>
#   <!--SIDEBAR END -->
#   <!-- BODY START -->
#   <div class="container" style="min-height:550px;">
#    <div class="row" style="padding-top:110px;">
#     <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
#      <script>
#       googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#      </script>
#     </div>
#     <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
#      <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#       For the best experience use
#       <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">
#        inshorts
#       </a>
#       app on your smartphone
#      </div>
#     </div>
#     <div class="card-stack">
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/new-feminism-has-come-up-in-india-urmila-on-kangana-calling-her-soft-porn-star-1600354986467" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="New feminism has come up in India: Urmila on Kangana calling her 'soft porn star'" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600354249995_211.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600354249995_211.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/new-feminism-has-come-up-in-india-urmila-on-kangana-calling-her-soft-porn-star-1600354986467" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'New%20feminism%20has%20come%20up%20in%20India%3A%20Urmila%20on%20Kangana%20calling%20her%20'soft%20porn%20star')' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           New feminism has come up in India: Urmila on Kangana calling her 'soft porn star'
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/new-feminism-has-come-up-in-india-urmila-on-kangana-calling-her-soft-porn-star-1600354986467">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T15:03:06.000Z" itemprop="datePublished">
#           08:33 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Reacting to Kangana Ranaut calling her 'soft porn star', actress Urmila Matondkar said, "It's shocking that while Kangana was saying all these things on national television the [female] anchor had a mad glee and crazy smile on her face." She added, "I think we should bow out and give way to this new feminism that has come up in India."
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/new-feminism-has-come-up-in-india-urmila-on-kangana-calling-her-soft-porn-star-1600354986467">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T15:03:06.000Z" itemprop="dateModified">
#           08:33 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://m.hindustantimes.com/bollywood/urmila-matondkar-reacts-to-kangana-ranaut-s-soft-porn-star-insult-will-those-who-opposed-shiv-sena-s-slur-for-kangana-condemn-this-too/story-Gyz4s5bf3UQCJ5C06eLAoJ_amp.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Hindustan%20Times' });" target="_blank">
#           Hindustan Times
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/amit-shah-discharged-from-aiims-was-admitted-for-post-covid19-checkup-1600350989789" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Kiran Khatri" itemprop="name">
#         </span>
#        </span>
#        <span content="Amit Shah discharged from AIIMS; was admitted for post COVID-19 checkup " itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600349135851_108.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600349135851_108.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/amit-shah-discharged-from-aiims-was-admitted-for-post-covid19-checkup-1600350989789" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Amit%20Shah%20discharged%20from%20AIIMS%3B%20was%20admitted%20for%20post%20COVID-19%20checkup%20)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Amit Shah discharged from AIIMS; was admitted for post COVID-19 checkup
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/amit-shah-discharged-from-aiims-was-admitted-for-post-covid19-checkup-1600350989789">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Kiran Khatri
#          </span>
#          /
#          <span class="time" content="2020-09-17T13:56:29.000Z" itemprop="datePublished">
#           07:26 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Home Minister Amit Shah has been discharged from AIIMS, Delhi, four days after he was admitted for a complete medical checkup before Parliament session. He was earlier admitted to the hospital for post COVID-19 care after he complained of fatigue and body aches and was discharged on August 31. The Home Minister had tested positive for COVID-19 on August 2.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/amit-shah-discharged-from-aiims-was-admitted-for-post-covid19-checkup-1600350989789">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Kiran Khatri
#          </span>
#          /
#          <span class="time" content="2020-09-17T13:56:29.000Z" itemprop="dateModified">
#           07:26 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://twitter.com/ANI/status/1306586732674953221?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">
#           Twitter
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/england-allrounder-david-willey-wife-test-positive-for-covid19-1600359692092" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="England all-rounder David Willey, wife test positive for COVID-19" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600358970573_958.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600358970573_958.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/england-allrounder-david-willey-wife-test-positive-for-covid19-1600359692092" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'England%20all-rounder%20David%20Willey%2C%20wife%20test%20positive%20for%20COVID-19)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           England all-rounder David Willey, wife test positive for COVID-19
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/england-allrounder-david-willey-wife-test-positive-for-covid19-1600359692092">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:21:32.000Z" itemprop="datePublished">
#           09:51 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          England all-rounder David Willey and his wife have tested positive for COVID-19, the player announced on social media on Thursday. The 30-year-old fast bowler last played for England in the ODI series against Ireland last month. The Yorkshire player said he was “gutted to be missing the remaining (group) games” of the domestic T20 league Vitality Blast.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/england-allrounder-david-willey-wife-test-positive-for-covid19-1600359692092">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:21:32.000Z" itemprop="dateModified">
#           09:51 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/csk-award-ravindra-jadeja-a-golden-sword-share-pic-1600359395698" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="CSK award Ravindra Jadeja a golden sword, share pic" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600358709222_894.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600358709222_894.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/csk-award-ravindra-jadeja-a-golden-sword-share-pic-1600359395698" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'CSK%20award%20Ravindra%20Jadeja%20a%20golden%20sword%2C%20share%20pic)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           CSK award Ravindra Jadeja a golden sword, share pic
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/csk-award-ravindra-jadeja-a-golden-sword-share-pic-1600359395698">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:16:35.000Z" itemprop="datePublished">
#           09:46 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          Chennai Super Kings awarded their all-rounder Ravindra Jadeja a golden sword for being the most successful left-arm spinner in the IPL. CSK coach Stephen Fleming and captain MS Dhoni presented Jadeja with the award. "Playing for this amazing franchise is an honor and an opportunity I cherish. Looking forward to the season," Jadeja tweeted.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/csk-award-ravindra-jadeja-a-golden-sword-share-pic-1600359395698">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:16:35.000Z" itemprop="dateModified">
#           09:46 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.crictracker.com/ipl-2020-chennai-super-kings-gift-a-golden-sword-to-ravindra-jadeja-for-his-outstanding-all-round-feat/amp/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">
#           CricTracker
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="div-gpt-ad-1536748319959-bqkb9vls-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
#       <script>
#        googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-bqkb9vls-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-bqkb9vls-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/latest-rankings-for-odi-batsmen-out-kohli-and-rohit-remain-on-top-1600359212557" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="Latest rankings for ODI batsmen out, Kohli and Rohit remain on top" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600358999811_638.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600358999811_638.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/latest-rankings-for-odi-batsmen-out-kohli-and-rohit-remain-on-top-1600359212557" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Latest%20rankings%20for%20ODI%20batsmen%20out%2C%20Kohli%20and%20Rohit%20remain%20on%20top)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Latest rankings for ODI batsmen out, Kohli and Rohit remain on top
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/latest-rankings-for-odi-batsmen-out-kohli-and-rohit-remain-on-top-1600359212557">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:13:32.000Z" itemprop="datePublished">
#           09:43 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          The ICC on Thursday released the latest rankings for ODI batsmen, with Virat Kohli and Rohit Sharma retaining their first and second positions respectively. England's Jonny Bairstow, who smashed a hundred against Australia on Thursday, has jumped three places to be ranked tenth. Meanwhile, Australia opener David Warner dropped two places to be ranked eighth.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/latest-rankings-for-odi-batsmen-out-kohli-and-rohit-remain-on-top-1600359212557">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:13:32.000Z" itemprop="dateModified">
#           09:43 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.crictracker.com/icc-release-latest-odi-rankings-virat-kohli-and-rohit-sharma-steal-the-top-honour/amp/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">
#           CricTracker
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/latest-rankings-for-odi-bowlers-out-archer-jumps-18-spots-to-10th-1600359822405" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Anmol Sharma" itemprop="name">
#         </span>
#        </span>
#        <span content="Latest rankings for ODI bowlers out, Archer jumps 18 spots to 10th " itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600359329428_22.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600359329428_22.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/latest-rankings-for-odi-bowlers-out-archer-jumps-18-spots-to-10th-1600359822405" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Latest%20rankings%20for%20ODI%20bowlers%20out%2C%20Archer%20jumps%2018%20spots%20to%2010th%20)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Latest rankings for ODI bowlers out, Archer jumps 18 spots to 10th
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/latest-rankings-for-odi-bowlers-out-archer-jumps-18-spots-to-10th-1600359822405">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:23:42.000Z" itemprop="datePublished">
#           09:53 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          The ICC today released the latest rankings for ODI bowlers. England fast bowler Jofra Archer jumped 18 spots to a career-best ranking of 10th. Meanwhile, England all-rounder Chris Woakes jumped three places to be ranked fourth. New Zealand pacer Trent Boult leads the ranking, while Team India fast bowler Jasprit Bumrah is ranked second.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/latest-rankings-for-odi-bowlers-out-archer-jumps-18-spots-to-10th-1600359822405">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Anmol Sharma
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:23:42.000Z" itemprop="dateModified">
#           09:53 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.instagram.com/p/CFOxlcIgmvD/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'ICC' });" target="_blank">
#           ICC
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/astronomers-detect-first-possible-intact-planet-orbiting-a-dead-star-1600359091254" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Nandini Sinha" itemprop="name">
#         </span>
#        </span>
#        <span content="Astronomers detect first possible intact planet orbiting a dead star" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600356608966_108.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600356608966_108.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/astronomers-detect-first-possible-intact-planet-orbiting-a-dead-star-1600359091254" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Astronomers%20detect%20first%20possible%20intact%20planet%20orbiting%20a%20dead%20star)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Astronomers detect first possible intact planet orbiting a dead star
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/astronomers-detect-first-possible-intact-planet-orbiting-a-dead-star-1600359091254">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Nandini Sinha
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:11:31.000Z" itemprop="datePublished">
#           09:41 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          An international team of astronomers has reported what may be the first intact planet found closely orbiting a white dwarf or a dead star, using NASA's Transiting Exoplanet Survey Satellite (TESS) and retired Spitzer Space Telescope. The exoplanet, known as 'WD 1856 b', is the size of Jupiter. It completes one full orbit every 1.4 days.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/astronomers-detect-first-possible-intact-planet-orbiting-a-dead-star-1600359091254">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Nandini Sinha
#          </span>
#          /
#          <span class="time" content="2020-09-17T16:11:31.000Z" itemprop="dateModified">
#           09:41 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.nasa.gov/press-release/nasa-missions-spy-first-possible-survivor-planet-hugging-white-dwarf-star?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'NASA' });" target="_blank">
#           NASA
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/charge-exminister-shourie-over-2002-rajasthan-hotel-sale-cbi-court-1600355990314" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Kiran Khatri" itemprop="name">
#         </span>
#        </span>
#        <span content="Charge ex-minister Shourie over 2002 Rajasthan hotel sale: CBI court" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# ...
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Shailesh" itemprop="name">
#         </span>
#        </span>
#        <span content="219 prisoners escape with 15 AK-47 rifles in Uganda" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600355600733_479.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600355600733_479.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/219-prisoners-escape-with-15-ak47-rifles-in-uganda-1600357091454" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': '219%20prisoners%20escape%20with%2015%20AK-47%20rifles%20in%20Uganda)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           219 prisoners escape with 15 AK-47 rifles in Uganda
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/219-prisoners-escape-with-15-ak47-rifles-in-uganda-1600357091454">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-09-17T15:38:11.000Z" itemprop="datePublished">
#           09:08 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          A military spokeswoman said that 219 prisoners escaped from a Ugandan jail with at least 15 AK-47 rifles, 20 magazines and other ammunition. Reportedly, some of them stripped half-naked to avoid being identified as prisoners. "They've had a whole night to disperse and hide, it complicates our efforts but we shall get them," the spokeswoman further said.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/219-prisoners-escape-with-15-ak47-rifles-in-uganda-1600357091454">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-09-17T15:38:11.000Z" itemprop="dateModified">
#           09:08 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://mobile.reuters.com/article/amp/idUSKBN2680M1?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Reuters' });" target="_blank">
#           Reuters
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="">
#       <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
#        <span content="" itemid="https://inshorts.com/en/news/pak-govt-freezes-964-assets-of-jamaatuddawa-jaishemohammed-1600357925227" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage">
#        </span>
#        <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
#         <span content="Shailesh" itemprop="name">
#         </span>
#        </span>
#        <span content="Pak Govt freezes 964 assets of Jamaat-ud-Dawa, Jaish-e-Mohammed" itemprop="description">
#        </span>
#        <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
#         <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600354107504_582.jpg?" itemprop="url"/>
#         <meta content="864" itemprop="width"/>
#         <meta content="483" itemprop="height"/>
#        </span>
#        <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
#         <span content="https://inshorts.com/" itemprop="url">
#         </span>
#         <span content="Inshorts" itemprop="name">
#         </span>
#         <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#          <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url">
#          </span>
#          <meta content="400" itemprop="width"/>
#          <meta content="60" itemprop="height"/>
#         </span>
#        </span>
#        <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/09_sep/17_thu/img_1600354107504_582.jpg?')">
#        </div>
#        <div class="news-card-title news-right-box">
#         <a class="clickable" href="/en/news/pak-govt-freezes-964-assets-of-jamaatuddawa-jaishemohammed-1600357925227" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Pak%20Govt%20freezes%20964%20assets%20of%20Jamaat-ud-Dawa%2C%20Jaish-e-Mohammed)' });" style="color:#44444d!important">
#          <span itemprop="headline">
#           Pak Govt freezes 964 assets of Jamaat-ud-Dawa, Jaish-e-Mohammed
#          </span>
#         </a>
#         <div class="news-card-author-time news-card-author-time-in-title">
#          <a href="/prev/en/news/pak-govt-freezes-964-assets-of-jamaatuddawa-jaishemohammed-1600357925227">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-09-17T15:52:05.000Z" itemprop="datePublished">
#           09:22 pm
#          </span>
#          on
#          <span clas="date">
#           17 Sep 2020,Thursday
#          </span>
#         </div>
#        </div>
#        <div class="news-card-content news-right-box">
#         <div itemprop="articleBody">
#          The Pakistani government has frozen 964 properties of banned terror groups Jamaat-ud-Dawa (JuD) and Jaish-e-Mohammed (JeM), the Interior Ministry said. Of these, 907 belonged to Hafiz Saeed-led JuD and 57 belonged to Masood Azhar-led JeM, it added. Reportedly, Pakistan's actions are part of its efforts to comply with the Financial Action Task Force's (FATF) 27-point action plan.
#         </div>
#         <div class="news-card-author-time news-card-author-time-in-content">
#          <a href="/prev/en/news/pak-govt-freezes-964-assets-of-jamaatuddawa-jaishemohammed-1600357925227">
#           <span class="short">
#            short
#           </span>
#          </a>
#          by
#          <span class="author">
#           Shailesh
#          </span>
#          /
#          <span class="time" content="2020-09-17T15:52:05.000Z" itemprop="dateModified">
#           09:22 pm
#          </span>
#          on
#          <span class="date">
#           17 Sep
#          </span>
#         </div>
#        </div>
#        <div class="news-card-footer news-right-box">
#         <div class="read-more">
#          read more at
#          <a class="source" href="https://www.siasat.com/pakistan-government-freezes-over-900-assets-of-jamat-ud-dawa-jaish-e-mohammad-1976002/amp/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'The%20Siasat%20Daily' });" target="_blank">
#           The Siasat Daily
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="load-more-wrapper">
#      <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">
#       Load More
#      </div>
#      <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;">
#       <img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/>
#      </div>
#     </div>
#     <div class="my-red app-download-pane hide-on-large-only">
#      <div class="container">
#       <div class="row">
#        <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#         For the best experience use
#         <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">
#          inshorts
#         </a>
#         app on your smartphone
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- BODY END -->
#   <footer class="page-footer teals">
#    <div class="container">
#     <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
#      <div class="col offset-l3 l3 m4 s12 right social-admin">
#       <div class="social-share">
#        <a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/facebook.png"/>
#        </a>
#       </div>
#       <div class="social-share">
#        <a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/twitter.png"/>
#        </a>
#       </div>
#       <div class="social-share">
#        <a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank">
#         <img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/>
#        </a>
#       </div>
#      </div>
#      <div class="col m4 l3 s6 footer-left-pane">
#       <div class="right">
#        <img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/>
#       </div>
#       <div class="copy-text">
#        <span>
#         <span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">
#          inshorts
#         </span>
#         medialabs pvt. ltd.
#        </span>
#        <br/>
#        ©
#        <span style="font-size:12px">
#         COPYRIGHT 2020
#        </span>
#       </div>
#      </div>
#      <div class="col m4 l3 s6 footer-right-pane">
#       <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;">
#        <img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/>
#       </div>
#       <div class="terms-text">
#        <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank">
#         <span>
#          Terms &amp; conditions
#         </span>
#         <br/>
#         <span>
#          Privacy Policies
#         </span>
#        </a>
#        <br/>
#        <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
#         <span>
#          Editorial Policy
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal_contact row" id="contactUsModal">
#     <!-- Modal content -->
#     <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
#      <span class="close">
#       ×
#      </span>
#      <div class="contact">
#       <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Hiring Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Admin Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Marketing Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Editorial Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact Sales Team
#        </button>
#       </a>
#      </div>
#      <div class="contact">
#       <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
#        <button id="myBtn">
#         Contact For Any Other Query
#        </button>
#       </a>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script>
#    var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
#   </script>
#   <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js">
#   </script>
#   <script src="/dist/scripts/index.js" type="text/javascript">
#   </script>
#   <script src="/dist/scripts/read.js" type="text/javascript">
#   </script>
#   <script src="/dist/scripts/jquery.scrolldepth.min.js">
#   </script>
#   <script type="text/javascript">
#    var min_news_id = "jn99e3zh-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
#   <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
#  </body>
# </html>

# %%
# Now since we have the whole page HTML,
# we can extract the any text we would wish to like.

all_news_map = {}

# Observing the pattern of the web page, we can see that 
# all news in the webpage are covered under their div tags 
# which contain news-card class.

all_news_cards = bs4obj.findAll('div', {"class": "news-card"})

# We loop through all news object in order to find the 
# news heading and its corresponding news body.

for newsObj in all_news_cards:
    # Finding span tag under newsObj with attribute itemprop 
    # set to description and extracting the value of its content.
    
    news_headline = newsObj.find('span', {"itemprop": "description"})['content']
    
    # Finding the div under newsObj having attribute itemprop 
    # set to articleBody and extracting its inner text.
    
    news_body = newsObj.find('div', {"itemprop": "articleBody"}).text
    
    # Adding a key with news heading and it body as its value.

    all_news_map[news_headline] = news_body

# %%
# Its time to get the news articles clustered. So 
# calling the create_cluster function we created 
# earlier for this. For passing on, we have news map 
# object and the maximum number of clusters, we wish
# the algorithm to output. 

clustering_result, news_article_mapping = create_cluster(all_news_map, 
                                                         num_clusters=10)

# %%
# Creating a text wrapper object to display the cluster results
# and prevents it from overflowing.

wrapper = textwrap.TextWrapper(width=120, initial_indent='\t\t', subsequent_indent='\t\t')

# Looping over all the items in the clustering_result

for cluster, news_headlines in clustering_result.items():
    print(cluster)
    for headline in news_headlines:
      print('\t', headline)
      for text in wrapper.wrap(news_article_mapping[headline]):
        print(text)
      print('\n')
# Out:
# Cluster 1
# 	 Harsimrat Badal to quit as Union Minister in protest against farm bills: SAD Prez
# 		Harsimrat Kaur Badal of BJP ally Shiromani Akali Dal (SAD) will resign as Union Minister in protest against three farm
# 		bills, SAD President Sukhbir Singh Badal announced in Lok Sabha on Thursday. Sukhbir Singh Badal said the proposed
# 		laws will "destroy" the 50 years of hard work done by successive Punjab governments to build the farm sector.
#
#
# 	 3,245 contract brucellosis caused by leak at biopharma factory in China last year
# 		Health Commission of China's Lanzhou confirmed that 3,245 people had contracted bacterial disease brucellosis in an
# 		outbreak caused by a leak at a biopharmaceutical company in December 2019. Another 1,401 people have tested as
# 		preliminarily positive. The factory used expired disinfectant while producing Brucella vaccines for animal use, which
# 		led to not all bacteria being eradicated in waste gas.
#
#
# 	 Depression needs to be treated like any other illness: Gulshan Devaiah
# 		Actor Gulshan Devaiah has said many people think depression is an emotion. "[It] is used as...expression to express
# 		something," he said, adding, "Like, if I proposed to a girl and she turned me down and I say 'I'm depressed', and
# 		(treat) depression as a state of mind." "It needs to be treated like any other illness like cancer...tuberculosis,"
# 		Gulshan said.
#
#
# 	 219 prisoners escape with 15 AK-47 rifles in Uganda
# 		A military spokeswoman said that 219 prisoners escaped from a Ugandan jail with at least 15 AK-47 rifles, 20 magazines
# 		and other ammunition. Reportedly, some of them stripped half-naked to avoid being identified as prisoners. "They've
# 		had a whole night to disperse and hide, it complicates our efforts but we shall get them," the spokeswoman further
# 		said.
#
#
# Cluster 2
# 	 Amit Shah discharged from AIIMS; was admitted for post COVID-19 checkup
# 		Home Minister Amit Shah has been discharged from AIIMS, Delhi, four days after he was admitted for a complete medical
# 		checkup before Parliament session. He was earlier admitted to the hospital for post COVID-19 care after he complained
# 		of fatigue and body aches and was discharged on August 31. The Home Minister had tested positive for COVID-19 on
# 		August 2.
#
#
# 	 England all-rounder David Willey, wife test positive for COVID-19
# 		England all-rounder David Willey and his wife have tested positive for COVID-19, the player announced on social media
# 		on Thursday. The 30-year-old fast bowler last played for England in the ODI series against Ireland last month. The
# 		Yorkshire player said he was “gutted to be missing the remaining (group) games” of the domestic T20 league Vitality
# 		Blast.
#
#
# 	 Don't turn disagreements on COVID-19 into political football: WHO
# 		The World Health Organization (WHO) urged governments and scientific institutions to not turn disagreements on the
# 		ways to deal with COVID-19 into some kind of political football. They need to review the developments and deliver them
# 		in an easy-to-understand manner so people can take the appropriate action, it said. It's important to have consistent
# 		messages from them, the WHO added.
#
#
# Cluster 3
# 	 New feminism has come up in India: Urmila on Kangana calling her 'soft porn star'
# 		Reacting to Kangana Ranaut calling her 'soft porn star', actress Urmila Matondkar said, "It's shocking that while
# 		Kangana was saying all these things on national television the [female] anchor had a mad glee and crazy smile on her
# 		face." She added, "I think we should bow out and give way to this new feminism that has come up in India."
#
#
# 	 Delhi airport opens India's 1st private jet terminal
# 		Civil Aviation Minister Hardeep Singh Puri has inaugurated India's first General Aviation Terminal facility at Delhi's
# 		Indira Gandhi International (IGI) Airport. The terminal, which is exclusive for private jets, has 57 parking bays. It
# 		can cater to 150 private movements per day, and can handle over 50 passengers every hour, Delhi International Airport
# 		Limited (DIAL) said.
#
#
# 	 Salman Khan's Tiger 3 to be shot across 7 countries: Reports
# 		The third instalment of the Tiger franchise will reportedly be shot across seven countries. Director Maneesh Sharma
# 		and his team will reportedly conduct a recce for Salman Khan-starrer film across the UAE, Istanbul and the US in
# 		December. "Rest of the countries have yet to be pencilled in. Maneesh and...[Aditya Chopra]...want to take it on
# 		floors by February," reports said.
#
#
# 	 Urmila has more than proved her versatile talent: RGV on Kangana's remark
# 		Taking to Twitter, filmmaker Ram Gopal Varma shared a clip from Kangana Ranaut's interview wherein she called Urmila
# 		Matondkar a "soft porn star". "Not wanting to get into slanging matches with anyone, I believe that @UrmilaMatondkar
# 		has more than proved her versatile talent in enacting such diversely complex roles as in 'Rangeela', 'Satya', 'Bhoot',
# 		'Ek Hasina Thi'," he tweeted.
#
#
# 	 Focus has deviated to irrelevant information: Himansh on Sushant's case
# 		Actor Himansh Kohli, while talking about Sushant Singh Rajput's death case, said, "In the past 10-15 days, I haven't
# 		come across anything that tells me that the objective of the case is being met." "The focus has...deviated to
# 		drugs...and all sorts of irrelevant information that still doesn't prove who the culprit is or take us anywhere near
# 		to...truth," he added.
#
#
# Cluster 4
# 	 Charge ex-minister Shourie over 2002 Rajasthan hotel sale: CBI court
# 		A CBI court has ordered registration of criminal cases against former Union Minister Arun Shourie and four others over
# 		alleged corruption in the sale of a government-run hotel in Rajasthan in 2002. The court didn't accept the CBI's
# 		closure report which cited lack of evidence. The Laxmi Vilas Palace Hotel was allegedly sold at a loss of ₹244 crore.
#
#
# 	 Acquit all accused in Babri demolition case: Litigant Ansari to CBI court
# 		Iqbal Ansari, a litigant in the Ram Janmabhoomi-Babri Masjid title suit, has urged a CBI court to acquit all 32
# 		accused in the demolition case, ahead of a hearing on September 30. After the Supreme Court's 2019 verdict, there's
# 		"no dispute left", he said. BJP veterans LK Advani, MM Joshi and Uma Bharti are among those accused in the case.
#
#
# Cluster 5
# 	 Astronomers detect first possible intact planet orbiting a dead star
# 		An international team of astronomers has reported what may be the first intact planet found closely orbiting a white
# 		dwarf or a dead star, using NASA's Transiting Exoplanet Survey Satellite (TESS) and retired Spitzer Space Telescope.
# 		The exoplanet, known as 'WD 1856 b', is the size of Jupiter. It completes one full orbit every 1.4 days.
#
#
# 	 Amazon announces first recipients of $2bn Climate Pledge Fund
# 		Amazon, on Thursday, announced electric automaker Rivian and JB Straubel-led recycling startup Redwood Materials as
# 		its first recipients of the $2 billion Climate Pledge Fund. In June, the company had said it would invest in
# 		sustainable technologies to reach its goal of net zero carbon by 2040. Other recipients of the fund include CarbonCure
# 		Technologies, Pachama and Turntide Technologies.
#
#
# Cluster 6
# 	 Australia's ex-PM Tony Abbott hacked after sharing boarding pass on Instagram
# 		Former Australian Prime Minister Tony Abbott had his phone number and passport details obtained by a hacker after he
# 		posted a picture of his boarding pass on Instagram in March. Hacker Alex Hope published a blog post on Wednesday
# 		saying that he spent several months trying to alert Qantas airline, the Australian government and Abbott himself about
# 		the security breach.
#
#
# 	 Shapoorji Pallonji sends notice to Tata Sons board for blocking fundraising
# 		The Shapoorji Pallonji (SP) Group has sent a notice to the board of Tata Sons challenging its move to block the group
# 		from pledging its shares to raise funds. The board has three days to respond, failing which the Mistry family will
# 		seek damages for the harm inflicted, a spokesperson said. The SP Group holds 18.4% stake in Tata Sons.
#
#
# Cluster 7
# 	 CSK award Ravindra Jadeja a golden sword, share pic
# 		Chennai Super Kings awarded their all-rounder Ravindra Jadeja a golden sword for being the most successful left-arm
# 		spinner in the IPL. CSK coach Stephen Fleming and captain MS Dhoni presented Jadeja with the award. "Playing for this
# 		amazing franchise is an honor and an opportunity I cherish. Looking forward to the season," Jadeja tweeted.
#
#
# 	 11,616 Indians abroad have tested +ve for coronavirus: Govt
# 		Minister of State for External Affairs V Muraleedharan said 11,616 Indians abroad have tested positive for coronavirus
# 		as of September 10. Singapore has the highest number of cases at 4,618, followed by Bahrain at 2,639 and Kuwait at
# 		1,769, he added. Muraleedharan further said that 62,000 Indians in distress were helped using ₹22.5 crore from the
# 		Indian Community Welfare Fund.
#
#
# 	 Pak Govt freezes 964 assets of Jamaat-ud-Dawa, Jaish-e-Mohammed
# 		The Pakistani government has frozen 964 properties of banned terror groups Jamaat-ud-Dawa (JuD) and Jaish-e-Mohammed
# 		(JeM), the Interior Ministry said. Of these, 907 belonged to Hafiz Saeed-led JuD and 57 belonged to Masood Azhar-led
# 		JeM, it added. Reportedly, Pakistan's actions are part of its efforts to comply with the Financial Action Task Force's
# 		(FATF) 27-point action plan.
#
#
# Cluster 8
# 	 Latest rankings for ODI batsmen out, Kohli and Rohit remain on top
# 		The ICC on Thursday released the latest rankings for ODI batsmen, with Virat Kohli and Rohit Sharma retaining their
# 		first and second positions respectively. England's Jonny Bairstow, who smashed a hundred against Australia on
# 		Thursday, has jumped three places to be ranked tenth. Meanwhile, Australia opener David Warner dropped two places to
# 		be ranked eighth.
#
#
# 	 Latest rankings for ODI bowlers out, Archer jumps 18 spots to 10th
# 		The ICC today released the latest rankings for ODI bowlers. England fast bowler Jofra Archer jumped 18 spots to a
# 		career-best ranking of 10th. Meanwhile, England all-rounder Chris Woakes jumped three places to be ranked fourth. New
# 		Zealand pacer Trent Boult leads the ranking, while Team India fast bowler Jasprit Bumrah is ranked second.
#
#
# Cluster 9
# 	 Terrorist attack in Pulwama averted, 52-kg explosives found near highway
# 		A terrorist attack was averted after a joint search operation by the Army and police discovered 52-kg explosives near
# 		a highway in Awantipora tehsil of south Kashmir’s Pulwama district. During the operation, two plastic tanks were found
# 		with 416 high explosive gelatin sticks and 50 detonators. The detonators were destroyed by the bomb disposal squad on
# 		the spot.
#
#
# Cluster 10
# 	 Men convicted of rape to face surgical castration in Nigerian state
# 		The Governor of Nigeria's Kaduna state has signed a law that states that men convicted of rape will face surgical
# 		castration and anyone raping a child under age 14 will face the death penalty. The previous law carried a maximum
# 		penalty of 21 years imprisonment for the rape of an adult and life imprisonment for the rape of a child.
